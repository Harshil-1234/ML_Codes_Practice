# %%
import pandas as pd

# %%
import requests

# %%
url = "https://foodprint.p.rapidapi.com/api/foodprint/footprint/0.8"

headers = {
	"X-RapidAPI-Key": "34ed24d68cmsh5ecbb99c1b8c4e5p1d1cfajsn893e4f281216",
	"X-RapidAPI-Host": "foodprint.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# [{'group': 'drinks', 'category': 'soft drinks', 'french_name': "Boisson à l'amande", 'name': 'Almond drink not sweet, not fortified, prepacked', 'rating_quality': '2.21', 'footprint': '0.37161937'}, {'group': 'drinks', 'category': 'soft drinks', 'french_name': 'Jus de pomme, pur jus', 'name': 'Apple juice, pure juice', 'rating_quality': '2.38', 'footprint': '0.50060083'}, {'group': 'fruits, vegetables, pulses and oilseeds', 'category': 'fruits', 'french_name': 'Pomme Canada, pulpe, crue', 'name': 'Apple, Canada, pulp, raw', 'rating_quality': '2.26', 'footprint': '0.39651509'}, {'group': 'fruits, vegetables, pulses and oilseeds', 'category': 'fruits', 'french_name': 'Pomme, pulpe et peau, crue', 'name': 'Apple, pulp and peel, raw', 'rating_quality': '2.07', 'footprint': '0.39651509'}, {'group': 'fruits, vegetables, pulses and oilseeds', 'category': 'fruits', 'french_name': 'Pomme, pulpe, crue', 'name': 'Apple, pulp, raw', 'rating_quality': '2.03', 'footprint': '0.39651509'}, {'group':
# ...

# %%
df = pd.DataFrame(response.json())

# %%
df
# Out:
#                                        group                   category  \
# 0                                     drinks                soft drinks
# 1                                     drinks                soft drinks
# 2    fruits, vegetables, pulses and oilseeds                     fruits
# 3    fruits, vegetables, pulses and oilseeds                     fruits
# 4    fruits, vegetables, pulses and oilseeds                     fruits
# ..                                       ...                        ...
# 384                          cereal products        flour and pie dough
# 385                starters and mixed dishes               mixed dishes
# 386  fruits, vegetables, pulses and oilseeds                 vegetables
# 387  fruits, vegetables, pulses and oilseeds  potatoes and other tubers
# 388  fruits, vegetables, pulses and oilseeds  potatoes and other tubers
#
#                                   french_name  \
# 0                          Boisson à l'amande
# ...

# %%
# df.to_csv('carbonprint.csv')
